# %%
import pandas as pd

# %%
patients = pd.read_csv("patients.csv")
admissions = pd.read_csv("admissions.csv")
billing = pd.read_csv("billing.csv")
departments = pd.read_csv("departments.csv")
doctors = pd.read_csv("doctors.csv")
staff = pd.read_csv("staff.csv")
beds = pd.read_csv("beds.csv")
resources = pd.read_csv("resources.csv")

# %%
print("Patients:", patients.shape)
print("Admissions:", admissions.shape)
print("Billing:", billing.shape)
print("Doctors:", doctors.shape)
print("Departments:", departments.shape)
print("Beds:", beds.shape)
print("Staff:", staff.shape)
print("Resources:", resources.shape)
# Out:
# Patients: (5050, 8)
# Admissions: (5790, 10)
# Billing: (5750, 7)
# Doctors: (90, 5)
# Departments: (8, 4)
# Beds: (450, 5)
# Staff: (175, 5)
# Resources: (16, 5)

# %%
print(admissions["Patient_ID"].isin(patients["Patient_ID"]).all())
print(admissions["Doctor_ID"].isin(doctors["Doctor_ID"]).all())
print(admissions["Department_ID"].isin(departments["Department_ID"]).all())
print(admissions["Bed_ID"].isin(beds["Bed_ID"]).all())
print(billing["Admission_ID"].isin(admissions["Admission_ID"]).all())
# Out:
# True
# True
# True
# True
# True

# %%
print(billing["Patient_ID"].isin(patients["Patient_ID"]).all())
# Out:
# True
